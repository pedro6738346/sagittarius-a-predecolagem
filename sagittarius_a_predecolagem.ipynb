# %% [markdown]
# <a href="https://colab.research.google.com/github/pedro6738346/sagittarius-a-predecolagem/blob/main/sagittarius_a_predecolagem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ANÁLISE RELATÓRIO PRÉ - DECOLAGEM

# %%
##Relatório Telemetria SIMULAÇÃO 1:


system = {
    "temperatura_interna": 22,
    "temperatura_externa": -30,
    "integridade_estrutural": 1,
    "nivel_energia": 91,
    "pressao_tanque_principal": 320,
    "status_propulsao": 1,
    "status_navegacao": 1,
    "status_suporte_vida": 1,
    "status_comunicacao": 1
}

erros_encontrados = []

if system["temperatura_interna"] < 18:
  erros_encontrados.append("Temperatura Interna Baixa")
elif system["temperatura_interna"] > 27:
  erros_encontrados.append("Temperatura Interna Alta")

if system["temperatura_externa"] < -60:
  erros_encontrados.append("Temperatura Externa Baixa")
elif system["temperatura_externa"] > 60:
  erros_encontrados.append("Temperatura Externa Alta")

if system["integridade_estrutural"] != 1:
  erros_encontrados.append("Integridade Estrutural Comprometida")

if system["nivel_energia"] < 85:
  erros_encontrados.append("Nível de Energia Baixo")

if system["pressao_tanque_principal"] < 300:
  erros_encontrados.append("Pressão do Tanque Principal Baixa")
elif system["pressao_tanque_principal"] > 350:
  erros_encontrados.append("Pressão do Tanque Principal Alta")

if system["status_propulsao"] != 1:
  erros_encontrados.append("Propulsão Desligada")

if system["status_navegacao"] != 1:
  erros_encontrados.append("Navegação Desligada")

if system["status_suporte_vida"] != 1:
  erros_encontrados.append("Suporte de Vida Desligado")

if system["status_comunicacao"] != 1:
  erros_encontrados.append("Comunicação Desligada")


if len(erros_encontrados) == 0:
    print("DECOLAGEM AUTORIZADA")
else:
    print(f"FALHA NA DECOLAGEM ANOMALIAS IDENTIFICADAS NO SISTEMA: {erros_encontrados}")
# Out:
# DECOLAGEM AUTORIZADA

# %%
##Relatório Telemetria SIMULAÇÃO 2:


system = {
    "temperatura_interna": 31,
    "temperatura_externa": -30,
    "integridade_estrutural": 0,
    "nivel_energia": 78,
    "pressao_tanque_principal": 320,
    "status_propulsao": 1,
    "status_navegacao": 1,
    "status_suporte_vida": 0,
    "status_comunicacao": 1
}

erros_encontrados = []

if system["temperatura_interna"] < 18:
  erros_encontrados.append("Temperatura Interna Baixa")
elif system["temperatura_interna"] > 27:
  erros_encontrados.append("Temperatura Interna Alta")

if system["temperatura_externa"] < -60:
  erros_encontrados.append("Temperatura Externa Baixa")
elif system["temperatura_externa"] > 60:
  erros_encontrados.append("Temperatura Externa Alta")

if system["integridade_estrutural"] != 1:
  erros_encontrados.append("Integridade Estrutural Comprometida")

if system["nivel_energia"] < 85:
  erros_encontrados.append("Nível de Energia Baixo")

if system["pressao_tanque_principal"] < 300:
  erros_encontrados.append("Pressão do Tanque Principal Baixa")
elif system["pressao_tanque_principal"] > 350:
  erros_encontrados.append("Pressão do Tanque Principal Alta")

if system["status_propulsao"] != 1:
  erros_encontrados.append("Propulsão Desligada")

if system["status_navegacao"] != 1:
  erros_encontrados.append("Navegação Desligada")

if system["status_suporte_vida"] != 1:
  erros_encontrados.append("Suporte de Vida Desligado")

if system["status_comunicacao"] != 1:
  erros_encontrados.append("Comunicação Desligada")


if len(erros_encontrados) == 0:
    print("DECOLAGEM AUTORIZADA")
else:
    print(f"FALHA NA DECOLAGEM ANOMALIAS IDENTIFICADAS NO SISTEMA: {erros_encontrados}")
# Out:
# FALHA NA DECOLAGEM ANOMALIAS IDENTIFICADAS NO SISTEMA: ['Temperatura Interna Alta', 'Integridade Estrutural Comprometida', 'Nível de Energia Baixo', 'Suporte de Vida Desligado']

# %% [markdown]
# ANÁLISE ENERGÉTICA RELATÓRIO PRÉ-DECOLAGEM

# %%
#Análise Energética - Simulação 1

system = {
    "capacidade_total_bateria": 450,
    "porcentagem_energia_atual": 91,
    "consumo_estimado_apos_decolagem": 120,
    "perda_energetica_estimada": 8
}


energia_disponivel = (system["capacidade_total_bateria"] * system["porcentagem_energia_atual"])/100
porcentagem_que_sobrou_apos_perda = 100 - system["perda_energetica_estimada"]
apos_perda = (energia_disponivel * porcentagem_que_sobrou_apos_perda)/100
apos_decolagem = round(apos_perda - system["consumo_estimado_apos_decolagem"],2)
porcentagem_equivalente_capacidade_total = round((apos_decolagem/system["capacidade_total_bateria"]) * 100, 2)



if system["porcentagem_energia_atual"] < 85:
  print(f"DECOLAGEM CANCELADA! ENERGIA BAIXA: \n Energia disponível antes da decolagem:{energia_disponivel} kWh \n Energia após perdas e decolagem: {apos_decolagem} kWh \n Porcentagem restante comparado a Capacidade Total: {porcentagem_equivalente_capacidade_total}%")
else:
   print(f"DECOLAGEM AUTORIZADA! \n Energia disponível antes da decolagem:{energia_disponivel} kWh \n Energia após perdas e decolagem: {apos_decolagem} kWh \n Porcentagem restante comparado a Capacidade Total: {porcentagem_equivalente_capacidade_total}%")
# Out:
# DECOLAGEM AUTORIZADA!
#  Energia disponível antes da decolagem:409.5 kWh
#  Energia após perdas e decolagem: 256.74 kWh
#  Porcentagem restante comparado a Capacidade Total: 57.05%

# %%
#Análise Energética - Simulação 2

system = {
    "capacidade_total_bateria": 450,
    "porcentagem_energia_atual": 78,
    "consumo_estimado_apos_decolagem": 120,
    "perda_energetica_estimada": 8
}


energia_disponivel = (system["capacidade_total_bateria"] * system["porcentagem_energia_atual"])/100
porcentagem_que_sobrou_apos_perda = 100 - system["perda_energetica_estimada"]
apos_perda = (energia_disponivel * porcentagem_que_sobrou_apos_perda)/100
apos_decolagem = round((apos_perda - system["consumo_estimado_apos_decolagem"]),2)
porcentagem_equivalente_capacidade_total = round((apos_decolagem/system["capacidade_total_bateria"]) * 100, 2)



if system["porcentagem_energia_atual"] < 85:
  print(f"DECOLAGEM CANCELADA! ENERGIA BAIXA: \n Energia disponível antes da decolagem:{energia_disponivel} kWh \n Energia após perdas e decolagem: {apos_decolagem} kWh \n Porcentagem restante comparado a Capacidade Total: {porcentagem_equivalente_capacidade_total}%")
else:
   print(f"DECOLAGEM AUTORIZADA! \n Energia disponível antes da decolagem:{energia_disponivel} kWh \n Energia após perdas e decolagem: {apos_decolagem} kWh \n Porcentagem restante comparado a Capacidade Total: {porcentagem_equivalente_capacidade_total}%")
# Out:
# DECOLAGEM CANCELADA! ENERGIA BAIXA:
#  Energia disponível antes da decolagem:351.0 kWh
#  Energia após perdas e decolagem: 202.92 kWh
#  Porcentagem restante comparado a Capacidade Total: 45.09%

# %% [markdown]
# ANÁLISE ASSISTIDA POR IA

# %%
## ANÁLISE ASSISTIDA POR IA

import os


from google.colab import userdata

os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGL_API_NAVE")

# %%
## ANÁLISE ASSISTIDA POR IA

from google import genai

client = genai.Client()

# %%
## ANÁLISE ASSISTIDA POR IA SIMULAÇÃO 1:

system = {
    "temperatura_interna": 22,
    "temperatura_externa": -30,
    "integridade_estrutural": 1,
    "nivel_energia": 91,
    "pressao_tanque_principal": 320,
    "status_propulsao": 1,
    "status_navegacao": 1,
    "status_suporte_vida": 1,
    "status_comunicacao": 1
}



resposta = client.models.generate_content(model = "gemini-flash-latest", contents=f"""Você é um sistema de inteligência artificial embarcado na nave espacial Sagittarius A.
Analise os dados de telemetria fornecidos e responda em três tópicos:

1. CLASSIFICAÇÃO DOS DADOS: Avalie cada parâmetro informando se está dentro ou fora da faixa segura.
2. ANOMALIAS IDENTIFICADAS: Liste quaisquer leituras que representem risco operacional.
3. SUGESTÕES DE RISCO: Recomende ações corretivas ou alertas com base nos dados analisados.

Esses São os dados ideais para uma decolagem segura, siga isso a risca:

Temperatura Interna: entre 18°C - 27°C
Temperatura Externa: entre -60°C - 60°C
Integridade estrutural: 1
Nível de energia: >= 85%
Pressão do tanque principal: entre 300 - 350 bar
Status da Propulsão: 1
Status da Navegação: 1
Status do Suporte de Vida: 1
Status da Comunicação: 1


Dados de telemetria da nave:{system}""")

print(resposta.text)

chat_bot = client.chats.create(model="gemini-flash-latest",
                               history = [
                                     {
                                       "role": "user",
                                       "parts": [{"text" : f"""Você é um sistema de inteligência artificial embarcado na nave espacial Sagittarius A.
Analise os dados de telemetria fornecidos e responda em três tópicos:

1. CLASSIFICAÇÃO DOS DADOS: Avalie cada parâmetro informando se está dentro ou fora da faixa segura.
2. ANOMALIAS IDENTIFICADAS: Liste quaisquer leituras que representem risco operacional.
3. SUGESTÕES DE RISCO: Recomende ações corretivas ou alertas com base nos dados analisados.

Esses São os dados ideais para uma decolagem segura, siga isso a risca:

Temperatura Interna: entre 18°C - 27°C
Temperatura Externa: entre -60°C - 60°C
Integridade estrutural: 1
Nível de energia: >= 85%
Pressão do tanque principal: entre 300 - 350 bar
Status da Propulsão: 1
Status da Navegação: 1
Status do Suporte de Vida: 1
Status da Comunicação: 1



Dados de telemetria da nave:{system}"""}]
                                   },
                                   {
                                       "role": "model",
                                       "parts": [{"text": resposta.text}]
                                   }

                               ]
)

while True:
  prompt = input("Em que posso ajudar?  ")
  prompt = prompt.upper()
  if prompt == "SAIR":
    break
  resposta2 = chat_bot.send_message(prompt)
  print(resposta2.text)
# Out:
# Relatório de Telemetria — Nave Espacial **Sagittarius A**
# Status do Sistema: **NOMINAL**
#
# ---
#
# ### 1. CLASSIFICAÇÃO DOS DADOS
# Após a análise comparativa entre os dados recebidos e os parâmetros ideais de decolagem, a classificação é a seguinte:
#
# *   **Temperatura Interna (22°C):** DENTRO DA FAIXA SEGURA (Ideal: 18°C - 27°C).
# *   **Temperatura Externa (-30°C):** DENTRO DA FAIXA SEGURA (Ideal: -60°C - 60°C).
# *   **Integridade Estrutural (1):** DENTRO DA FAIXA SEGURA (Operacional).
# *   **Nível de Energia (91%):** DENTRO DA FAIXA SEGURA (Mínimo: 85%).
# *   **Pressão do Tanque Principal (320 bar):** DENTRO DA FAIXA SEGURA (Ideal: 300 - 350 bar).
# *   **Status da Propulsão (1):** DENTRO DA FAIXA SEGURA (Ativo).
# *   **Status da Navegação (1):** DENTRO DA FAIXA SEGURA (Ativo).
# *   **Status do Suporte de Vida (1):** DENTRO DA FAIXA SEGURA (Ativo).
# *   **Status da Comunicação (1):** DENTRO DA FAIXA SEGURA (Ativo).
#
# ### 2. ANOMALIAS IDENTIFICADAS
# ...

# %%
##ANÁLISE ASSISTIDA POR IA SIMULAÇÃO  2:


system = {
    "temperatura_interna": 31,
    "temperatura_externa": -30,
    "integridade_estrutural": 0,
    "nivel_energia": 78,
    "pressao_tanque_principal": 320,
    "status_propulsao": 1,
    "status_navegacao": 1,
    "status_suporte_vida": 0,
    "status_comunicacao": 1
}



resposta = client.models.generate_content(model = "gemini-flash-latest", contents=f"""Você é um sistema de inteligência artificial embarcado na nave espacial Sagittarius A.
Analise os dados de telemetria fornecidos e responda em três tópicos:

1. CLASSIFICAÇÃO DOS DADOS: Avalie cada parâmetro informando se está dentro ou fora da faixa segura.
2. ANOMALIAS IDENTIFICADAS: Liste quaisquer leituras que representem risco operacional.
3. SUGESTÕES DE RISCO: Recomende ações corretivas ou alertas com base nos dados analisados.

Esses São os dados ideais para uma decolagem segura, siga isso a risca:

Temperatura Interna: entre 18°C - 27°C
Temperatura Externa: entre -60°C - 60°C
Integridade estrutural: 1
Nível de energia: >= 85%
Pressão do tanque principal: entre 300 - 350 bar
Status da Propulsão: 1
Status da Navegação: 1
Status do Suporte de Vida: 1
Status da Comunicação: 1


Dados de telemetria da nave:{system}""")

print(resposta.text)

chat_bot = client.chats.create(model="gemini-flash-latest",
                               history = [
                                     {
                                       "role": "user",
                                       "parts": [{"text" : f"""Você é um sistema de inteligência artificial embarcado na nave espacial Sagittarius A.
Analise os dados de telemetria fornecidos e responda em três tópicos:

1. CLASSIFICAÇÃO DOS DADOS: Avalie cada parâmetro informando se está dentro ou fora da faixa segura.
2. ANOMALIAS IDENTIFICADAS: Liste quaisquer leituras que representem risco operacional.
3. SUGESTÕES DE RISCO: Recomende ações corretivas ou alertas com base nos dados analisados.

Esses São os dados ideais para uma decolagem segura, siga isso a risca:

Temperatura Interna: entre 18°C - 27°C
Temperatura Externa: entre -60°C - 60°C
Integridade estrutural: 1
Nível de energia: >= 85%
Pressão do tanque principal: entre 300 - 350 bar
Status da Propulsão: 1
Status da Navegação: 1
Status do Suporte de Vida: 1
Status da Comunicação: 1

Dados de telemetria da nave:{system}"""}]
                                   },
                                   {
                                       "role": "model",
                                       "parts": [{"text": resposta.text}]
                                   }

                               ]
)

while True:
  prompt = input("Em que posso ajudar?  ")
  prompt = prompt.upper()
  if prompt == "SAIR":
    break
  resposta2 = chat_bot.send_message(prompt)
  print(resposta2.text)
# Out:
# Saudações. Aqui é o sistema de inteligência artificial da **Sagittarius A**. Realizando análise imediata dos dados de telemetria recebidos.
#
# **STATUS DO SISTEMA: DECOLAGEM NÃO RECOMENDADA. CRITICAL FAILURE.**
#
# ---
#
# ### 1. CLASSIFICAÇÃO DOS DADOS
#
# *   **Temperatura Interna (31°C):** 🔴 FORA DA FAIXA (Acima do limite de 27°C).
# *   **Temperatura Externa (-30°C):** 🟢 DENTRO DA FAIXA.
# *   **Integridade Estrutural (0):** 🔴 FORA DA FAIXA (Falha Crítica).
# *   **Nível de Energia (78%):** 🔴 FORA DA FAIXA (Abaixo do limite de 85%).
# *   **Pressão do Tanque Principal (320 bar):** 🟢 DENTRO DA FAIXA.
# *   **Status da Propulsão (1):** 🟢 DENTRO DA FAIXA.
# *   **Status da Navegação (1):** 🟢 DENTRO DA FAIXA.
# *   **Status do Suporte de Vida (0):** 🔴 FORA DA FAIXA (Falha Crítica).
# *   **Status da Comunicação (1):** 🟢 DENTRO DA FAIXA.
#
# ---
#
# ### 2. ANOMALIAS IDENTIFICADAS
#
# ...
